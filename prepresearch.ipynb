# %%
import pandas as pd
df = pd.read_csv('Drift20StoryFNReal.csv')
df
# Out:
#           1        2        3        4        5        6        7        8  \
# 0   0.00000  0.00000  0.74218  0.73595  0.75438  0.75438  0.73035  0.73468
# 1   0.00000  0.00000  0.95410  0.95410  0.95976  0.95976  0.94418  0.95691
# 2   0.00000  0.00000  2.94600  1.08550  1.07000  1.05510  1.07240  1.07790
# 3   0.00000  2.84000  2.78720  0.42798  0.43182  0.43182  2.90260  3.34650
# 4   0.00000  0.00000  2.80980  2.84080  2.76840  2.92650  0.39675  2.44260
# 5   0.00000  0.00000  2.77180  2.57340  2.65180  2.73950  2.91390  2.58100
# 6   0.00000  0.00000  0.30186  0.30249  0.30217  0.30401  0.00000  0.00000
# 7   0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 8   0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 9   1.74270  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 10  0.29450  0.29450  0.29450  0.29450  0.29450  0.00000  2.48970  0.00000
# ...

# %%
import pandas as pd
df2 = pd.read_csv('Drift20StoryFNSimulated.csv')
df2
# Out:
#           1        2        3        4        5        6        7        8  \
# 0   0.00000  0.00000  0.57741  0.61409  0.43117  0.36531  0.46628  0.38755
# 1   0.00000  0.00000  0.85487  0.83983  0.85008  0.57598  0.55069  0.52417
# 2   0.00000  0.00000  3.31190  1.71570  1.79290  0.88306  1.27430  1.37710
# 3   0.00000  2.53930  3.72700  0.45439  0.45642  0.34674  3.86690  3.45360
# 4   0.00000  0.00000  3.25830  2.98130  1.81980  1.58070  0.34355  2.31740
# 5   0.00000  0.00000  3.70360  3.26890  1.63530  1.42370  1.25260  1.75220
# 6   0.00000  0.00000  0.32285  0.28853  0.27886  0.23400  0.00000  0.00000
# 7   0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 8   0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 9   2.61900  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 10  0.27045  0.23739  0.22641  0.22390  0.20507  0.00000  1.60600  0.00000
# ...

# %%
col_count = df.shape[1] #returns num of col
i = 0
while i < col_count:
    if i % 39 == 0:
        df.plot()

        i = i + 1
    
    i = i + 1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [22], line 5
#       3 while i < col_count:
#       4     if i % 39 == 0:
# ----> 5         df.plot()
#       7         i = i + 1
#       9     i = i + 1
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     919 def __call__(self, *args, **kwargs):
# --> 920     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     922     x, y, kind, kwargs = self._get_call_args(
#     923         plot_backend.__name__, self._parent, args, kwargs
#     924     )
#     926     kind = self._kind_aliases.get(kind, kind)
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:1907, in _get_plot_backend(backend)
#    1904 if backend_str in _backends:
#    1905     return _backends[backend_str]
# ...
